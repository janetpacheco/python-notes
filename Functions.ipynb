# %% [markdown]
# ## Creating a function

# %%
def myFunc():
    print('Hello from my func')
    
    
myFunc()
# Out:
# Hello from my func

# %% [markdown]
# ## Arguments
# ### Passing a List as an Argument
#
# You can send any data types of argument to a function (string, number, list, dictionary etc.), and it will be treated as the same data type inside the function.

# %%
def getAverage(lstScores):
    sumTotal = 0
    for note in lstScores:
        sumTotal += note 
    return sumTotal/len(lstScores)

# %%
getAverage([10,5,10])
# Out:
# 8.333333333333334

# %% [markdown]
# ## Parameters or arguments?
#
#
# From a function's perspective:
#
# A parameter is the variable listed inside the parentheses in the function definition.
#
# An argument is the value that is sent to the function when it is called.

# %% [markdown]
# ## Number of arguments
# If your function expects 2 arguments, you have to call the function with 2 arguments, not more, and not less.
#
# ## Keyword arguments
#
#
# The phrase Keyword Arguments are often shortened to **kwargs** in Python documentations.

# %%
def printName(fName = 'Carol',lName = 'Boyton'):
    print('Hi '+ fName + ' ' + lName)

# %%
printName(fName='Agatha',lName='Christie')
# Out:
# Hi Agatha Christie

# %% [markdown]
# ## Default Parameter Value

# %%
printName()
# Out:
# Hi Carol Boyton

# %% [markdown]
# ## Arbitrary arguments *args
# If you don't know how many args that will be passed into your function, add * before the parameter name in the function definition.
#
# This way the function **will receive a tuple of arguments**, and can access the items accordingly:

# %%
def my_Function(*kids):
    print('The youngest child is ' + kids[2])

my_Function('Lily','Gabriel','Israel')
# Out:
# The youngest child is Israel

# %% [markdown]
# ## Arbitrary Keyword Arguments, **kwargs

# %% [markdown]
# **If you do not know how many keyword arguments** that will be passed into your function, add two asterisk: ** before the parameter name in the function definition.
#
# This way the function **will receive a dictionary of arguments**, and can access the items accordingly:

# %%
def thisFunc(**kid):
    print('Her last name is ' + kid['lName']) 

    
thisFunc(fName = 'Adelita', lName = 'de mi Corazón')
# Out:
# Her last name is de mi Corazón

# %% [markdown]
# ## The pass Statement
# Function definitions cannot be empty, but if you for some reason have a function definition with no content, put in the pass statement to avoid getting an error.

# %%
def myfunction():
    pass

# %% [markdown]
# ## Recursion
# A defined function can call itself.
#
# The developer should be very careful with recursion as it can be quite easy to slip into writing a function which never terminates, or one that uses excess amounts of memory or processor power. However, when written correctly recursion can be a very efficient and mathematically-elegant approach to programming

# %% [markdown]
# **Example :**

# %%
def tri_recursion(k): # *1 2  *2 1   *3  0
    if k > 0: #*1 2>0  *2 1>0 *3 0>0
        result = k + tri_recursion(k - 1) #*1 2 + tri(1)  *2  1+tri(0)
    else:
        result = 0 #*3 r=0
    return result #*3 r =0  *2 r=1  *1 r= 3

# %%
tri_recursion(2)
# Out:
# 3
