# %% [markdown]
# # List

# %% [markdown]
# Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are **Tuple**, **Set**, and **Dictionary**, all with different qualities and usage.

# %%
lst = ['husky','salchicha','maltes']
print(lst)
# Out:
# ['husky', 'salchicha', 'maltes']

# %% [markdown]
# List item are **ordered, changable**, and **allow duplicate values.**

# %%
fruits = ['manzana','banana','piña','manzana']
print(fruits)
# Out:
# ['manzana', 'banana', 'piña', 'manzana']

# %% [markdown]
# ## List length

# %%
print(len(fruits))
# Out:
# 4

# %% [markdown]
# ## List Items - Data types
# List items can be of any data type:

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, 4, 'hi']

# %%
type(list3)
# Out:
# list

# %% [markdown]
# ## The list() constructor
# It is also possible to use the list() constructor when creating a new list

# %%
lstC = list(('hola','cómo','tas','?'))
print(lstC)
# Out:
# ['hola', 'cómo', 'tas', '?']

# %% [markdown]
# # Collections (Arrays)
# There are **four** collection data types in the Python programming language:
#
# * **List**
# * **Tuple** is a collection which is **ordered** and **unchangeable**. **Allows duplicate** members.
# * **Set** is a colllection which is **unordered**,**unchangable** and **unindexed**. **No duplicate** members.
# * **Dictionary** is a collection which is **ordered** and **changeable**. **No duplicate** members

# %% [markdown]
# ## Access list items

# %%
lst = ['cherry','orange','piña']
print(lst[1:])
# Out:
# ['orange', 'piña']

# %% [markdown]
# ## Negative Indexing

# %%
print(lst[-1:])
# Out:
# ['piña']

# %%
print(lst[-1])
# Out:
# piña

# %% [markdown]
# ## Range of indexes

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
print(thislist[:3])
# Out:
# ['apple', 'banana', 'cherry']

# %%
print(thislist[1:])
# Out:
# ['banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
print(thislist[-5:-2])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
if 'guanabana' in fruits:
    print('Yes,"guanabana" in the fruits list')
else:
    print('No,"guanabana" isn\'t in fruits list')
# Out:
# No,"guanabana" isn't in fruits list

# %% [markdown]
# ## Change item value

# %%
fruits = ["apple", "banana", "cherry", "orange", "mango"]

# %%
fruits[0] = 'guayaba'
print(fruits)
# Out:
# ['guayaba', 'banana', 'cherry', 'orange', 'mango']

# %% [markdown]
# ## Change a range of item values

# %%
fruits.append('new')
print(fruits)
# Out:
# ['guayaba', 'banana', 'cherry', 'orange', 'mango', 'new']

# %%
fruits[1:4] = ['piña','manzana','watermelon']
print(fruits)
# Out:
# ['guayaba', 'piña', 'manzana', 'watermelon', 'mango', 'new']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] =  ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %% [markdown]
# ## Insert items
# To insert a new list item, **without replacing** any of the existing values, we can use the **insert()** method.

# %%
print(fruits)
# Out:
# ['guayaba', 'piña', 'manzana', 'watermelon', 'mango', 'new']

# %%
fruits.insert(1,'inserted')
print(fruits)
# Out:
# ['guayaba', 'inserted', 'piña', 'manzana', 'watermelon', 'mango', 'new']

# %% [markdown]
# ## Append items
# To add an item to the **end** of the list, use the append() method:

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("appended")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'appended']

# %% [markdown]
# ## Extend List
# To append elements from another list to the current list, use the extend() method

# %%
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'appended']

# %%
chiles = ['manzano','guajillo']
chiles.extend(thislist)
print(chiles)
# Out:
# ['manzano', 'guajillo', 'apple', 'banana', 'cherry', 'appended']

# %% [markdown]
# ## Add any iterable
# The extend() you can add any iterable object (tuples, sets, dictionaries etc.)

# %%
thislist = ["apple", "banana", "cherry"]
thistuple = ("kiwi", "orange")
thislist.extend(thistuple)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %% [markdown]
# ## Remove specified item.
# The **remove()** method removes the specified item.

# %%
print(thislist)
thislist.remove('kiwi')
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# ## Remove specified index.
# **pop()**

# %%
print(thislist)
thislist.pop(0)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['banana', 'cherry', 'orange']

# %%
print(thislist)
thislist.pop()
print(thislist)
# Out:
# ['banana', 'cherry', 'orange']
# ['banana', 'cherry']

# %% [markdown]
# The **del** keyword also removes the specified index:

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %% [markdown]
# The del keyword can also delete the list completely.

# %%
del thislist

# %% [markdown]
# ## Clear the list

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %% [markdown]
# # Loop lists
# ## Loop through a List

# %%
lst = ['Katy','Jack','Masha','Nala']
for p in lst:
    print(p)
# Out:
# Katy
# Jack
# Masha
# Nala

# %% [markdown]
# ## Loop through the Index Numbers
# Use the **range()** and **len()** functions to create a suitable iterable.

# %%
print(lst)
# Out:
# ['Katy', 'Jack', 'Masha', 'Nala']

# %%
for i in range(len(lst)):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(len(lst)):
    print(lst[i])
# Out:
# Katy
# Jack
# Masha
# Nala

# %% [markdown]
# ## Using a while loop

# %%
print(lst)
# Out:
# ['Katy', 'Jack', 'Masha', 'Nala']

# %%
i = 0
while i < len(lst):
    print(lst[i])
    i +=1
# Out:
# Katy
# Jack
# Masha
# Nala

# %% [markdown]
# ## Lopping using list comprehension

# %%
lst = ['Katy', 'Jack', 'Masha', 'Nala']
[print(p) for p in lst]
# Out:
# Katy
# Jack
# Masha
# Nala
# [None, None, None, None]

# %%
# Out:
# Katy
# Jack
# Masha
# Nala
# [None, None, None, None]

# %% [markdown]
# # List comprehension

# %%
names = ['Annie','Valen','Jackie']

# %%
newlst = []

# %%
for x in names:
    if 'i' in x:
        newlst.append(x) 
print(newlst)
# Out:
# ['Annie', 'Jackie']

# %% [markdown]
# Using **list comprehension**:
#
# The condition is like a filter that only accepts the items that valuate to True.
#
#
# newlist = [expression **for** item **in** iterable **if** condition == True]

# %%
newlst = [x for x in names if 'i' in x]
print(newlst)
# Out:
# ['Annie', 'Jackie']

# %%
fruits = ['mango','uvas','piña','apple']
newlst = [f for f in fruits if f !='apple']
print(newlst)
# Out:
# ['mango', 'uvas', 'piña']

# %% [markdown]
# The condition is optional and can be omitted:

# %%
newlist = [x for x in fruits] 
print(newlist)
# Out:
# ['mango', 'uvas', 'piña', 'apple']

# %% [markdown]
# ## Iterable

# %% [markdown]
# You can use the **range()** function to create an iterable:

# %%
newlist = [x for x in range(5)]
print(newlist)
# Out:
# [0, 1, 2, 3, 4]

# %%
newlist = [x for x in range(10) if x > 2]
print(newlist)
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ## Expression

# %%
lst = ['woffie','canelo','bingo']

# %% [markdown]
# nwList = [x.upper() for x in lst]
# print(nwList)

# %%
nwList2 = ['oui' for x in lst]
print(nwList2)
# Out:
# ['oui', 'oui', 'oui']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
nwList3 = [x if x != 'banana' else 'instead of banana' for x in fruits]
print(nwList3)
# Out:
# ['apple', 'instead of banana', 'cherry', 'kiwi', 'mango']

# %% [markdown]
# # Sort lists
# ## Sort list alphanumerically
# List objects have a sort() method that will sort the list alphanumerically, **ascending, by default**:

# %%
fruits = ["apple", "kiwi", "cherry", "melon", "mango","frambuesa"]
fruits.sort()
print(fruits)
# Out:
# ['apple', 'cherry', 'frambuesa', 'kiwi', 'mango', 'melon']

# %%
numbers = [34,29,90,87.2,87.1,5]
numbers.sort()
print(numbers)
# Out:
# [5, 29, 34, 87.1, 87.2, 90]

# %% [markdown]
# ## Sort descending
# To sort descending, use the keyword argument **reverse = True**:

# %%
tropical = ["orange", "mango", "kiwi", "pineapple", "banana"]
tropical.sort(reverse = True)
print(tropical)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
numbers = [34,29,90,87.2,87.1,5]
numbers.sort(reverse=True)
print(numbers)
# Out:
# [90, 87.2, 87.1, 34, 29, 5]

# %% [markdown]
# ## Customize sort function
# You can also customize your own function by using the keyword argument **key = function**.
#
# The function will return a number that will be used to sort the list (the lowest number first):
#
# **Example**: Sort the list based on how close the number is to 50:

# %%
def sortFunc(n):
    return abs(n-50)

lst = [100,50,40,85,48]
lst.sort(key = sortFunc)
print(lst)
# Out:
# [50, 48, 40, 85, 100]
# 0

# %% [markdown]
# **Example**: Sort the list based on how far the number is to 50:

# %%
def sortFunc2(n): 
    return abs(n-50)

lst = [100,50,40,85,48]
lst.sort(key=sortFunc2,reverse=True)
print(lst)
# Out:
# [100, 85, 40, 48, 50]

# %% [markdown]
# ## Case Insensitive sort
# By default the sort() method is case sensitive, resulting in all capital letters being sorted before lower case letters:

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort()
print(thislist)
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key = str.lower)
print(thislist)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %% [markdown]
# ## Reverse order
# What if you want to reverse the order of a list, regardless of the alphabet?

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %% [markdown]
# # Copy lists
# ## Copy a list
# You cannot copy a list simply by typing **list2 = list1**, because: **list2** will only be a reference to **list1**, and changes made in **list1** will automatically also be made in **list2**.
#
# There are ways to make a copy, one way is to use the built-in List method **copy()**.

# %%
tropical = ["apple", "banana", "cherry"]
mylst = tropical.copy()
print(mylst)
# Out:
# ['apple', 'banana', 'cherry']

# %%
tropical.pop()
print(tropical)
# Out:
# ['apple', 'banana']

# %%
print(mylst)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# Another way to make a copy is to use the built-in method **list()**.

# %%
thislist = ["apple", "banana", "cherry"]
myCopy = list(thislist)

# %%
thislist.insert(2,'coco')
print(thislist)
# Out:
# ['apple', 'banana', 'coco', 'cherry']

# %%
print(myCopy)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# ## Join Lists
# ### Join 2 lists
# There are several ways to join, or concatenate, two or more lists in Python.
#
# One of the easiest ways are by using the **+** operator.

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# Another way to join two lists is by **appending** all the items from list2 into list1, one by one:

# %%
for element in list2 :
    list1.append(element)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list1.append(list2)
print(list1)
# Out:
# ['a', 'b', 'c', [1, 2, 3]]

# %% [markdown]
# Or you can use the **extend()** method, which purpose is to add elements from one list to another list

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# # List Methods
# https://www.w3schools.com/python/python_lists_methods.asp
