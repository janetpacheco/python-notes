# %%
print('Boom! Big reveal! I turned myself into a pickle!')
# Out:
# Boom! Big reveal! I turned myself into a pickle!

# %% [markdown]
# # Python Indentation

# %%
if 28>30:
    print('It\'s greater')
print('28 is not greater than')
# Out:
# 28 is not greater than

# %% [markdown]
# # Variables
# ## Creating variables

# %%
x = 3.5
y = 'Katrushka Adelita de mi corazon'

# %%
print(x)
y
# Out:
# 3.5
# 'Katrushka Adelita de mi corazon'

# %% [markdown]
# ## Comments

# %%
"""
This is a comment written in
more than just one line
"""
print('Are you there?')
# Out:
# Are you there?

# %% [markdown]
# ## Casting

# %%
x = str(3) # will be '3'
y = int(3) # will be 3
z = float(3) #will be 3.0
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %% [markdown]
# ## Get the type

# %%
poorMorty = 'Morty, I need your help on an adventure.'
print(type(poorMorty))
# Out:
# <class 'str'>

# %% [markdown]
# ## Many values to multiple variables

# %%
x,y,z = 'Katy','Jack','3'
print(x)
print(y)
print(z)
# Out:
# Katy
# Jack
# 3

# %%
x = y = z = 'All together now'
print(x)
print(y)
print(z)
# Out:
# All together now
# All together now
# All together now

# %% [markdown]
# ## Unpacking a collection

# %%
animals = ['dog', 'tiger','cat']
j,l,m = animals
print(j)
print(l)
print(m)
# Out:
# dog
# tiger
# cat

# %% [markdown]
# ## Output variables

# %%
x = 'fucking'
print('You are '+ x + ' special https://youtu.be/ieeMc-uoaD8')
# Out:
# You are fucking special https://youtu.be/ieeMc-uoaD8

# %%
x = 'Coming soon'
y = ' I lava you'
z = x + y 
print(z)
# Out:
# Coming soon I lava you

# %%
x = 5
y = "John"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-00c66e4310ff> in <module>
#       1 x = 5
#       2 y = "John"
# ----> 3 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Global variables

# %%
x = 'Katrushka'
def myKaty():
    print(x + ' Adelita de mi corazón')
myKaty()
print(x)
# Out:
# Katrushka Adelita de mi corazón
# Katrushka

# %% [markdown]
# ## The global keyword
# If you use the global keyword, the variable belongs to the global scope:

# %%
def myFunc():
    global x
    x = 'maravilloso'
    print(x)
myFunc()

print('Hoy fue un día ' + x)
# Out:
# maravilloso
# Hoy fue un día maravilloso

# %% [markdown]
# To change the value of a global variable inside a function, refer to the variable by using the global keyword:

# %%
x = 'hola'
def myFunc():
    global x 
    x = 'adios'
myFunc()   
print(x)
# Out:
# adios

# %% [markdown]
# # Python Data types
# **Text Type:** 	str
#
# **Numeric Types:** 	int, float, complex
#
# **Sequence Types:** 	list, tuple, range
#
# **Mapping Type:** 	dict
#
# **Set Types:** 	set, frozenset
#
# **Boolean Type:** 	bool
#
# **Binary Types:** 	bytes, bytearray, memoryview

# %% [markdown]
# ## Getting the data type

# %%
c = 1j

lst = ["apple", "banana", "cherry"]

t = ("apple", "banana", "cherry")
print('tuple: {}'.format(t))

r = range(6)
print('range: {}'.format(r))

d = {"name" : "Joe", "age" : 36}
print('dictionary: {}'.format(d))

frs = frozenset({"apple", "banana", "cherry"})
print('frozenset: {}'.format(frs))

b = b"Hello"
print('bytes: {}'.format(b))

ba = bytearray(5)
print('bytearray: {}'.format(ba))

mv = memoryview(bytes(5))
print('bytearray: {}'.format(mv))
# Out:
# tuple: ('apple', 'banana', 'cherry')
# range: range(0, 6)
# dictionary: {'name': 'Joe', 'age': 36}
# frozenset: frozenset({'cherry', 'apple', 'banana'})
# bytes: b'Hello'
# bytearray: bytearray(b'\x00\x00\x00\x00\x00')
# bytearray: <memory at 0x000001DE5D396700>

# %% [markdown]
# ## Setting the Specific Data Type

# %%
x = list(("apple", "banana", "cherry"))
print(x)
# Out:
# ['apple', 'banana', 'cherry']

# %%
x = memoryview(bytes(5))
print(x)

# %%
x = set(("apple", "banana", "cherry"))
print(x)
# Out:
# {'cherry', 'apple', 'banana'}

# %% [markdown]
# # Python Numbers
# There are three numeric types in Python:
# * int
# * float
# * complex

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex
w = x + z 
print(w)
# Out:
# (1+1j)

# %% [markdown]
# ## Float
# Float can also be scientific numbers with an "e" to indicate the power of 10.

# %%
 x = 35e3
y = 12E4
z = -87.7e100

print(x)
print(type(y))
print(type(z))
# Out:
# 35000.0
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ## Type conversion

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)
# Out:
# 1.0
# 2
# (1+0j)

# %% [markdown]
# ## Random Number
# Python does not have a random() function to make a random number, but Python has a built-in module called random that can be used to make random numbers:

# %%
import random

print(random.randrange(1, 10))
# Out:
# 8

# %% [markdown]
# # Classes and Objects

# %%
def scope_test():
    def do_local():
        spam = "local spam"
    def do_nonlocal():
        nonlocal spam
        spam = "nonlocal spam"
    def do_global():
        global spam
        spam = "global spam"
        
    spam = "test spam"
    do_local()
    print("After local assignment:", spam)
    do_nonlocal()
    print("After nonlocal assignment:", spam)
    do_global()
    print("After global assignment:", spam)

scope_test()
print('In global scope',spam)

# %% [markdown]
# ## Inheritance

# %%
# parent class
class Person( object ):    
  
        # __init__ is known as the constructor         
        def __init__(self, name, lname , age):   
                self.fname = fname
                self.idnumber = age
        def display(self):
                print(self.name)
                print(self.idnumber)
#child class
class Employee( Person ):           
    def __init__(self, name, idnumber, salary, post):
        self.salary = salary
        self.post = post
  
                # invoking the __init__ of the parent class 
        Person.__init__(self, name, idnumber) 
  
                  
# creation of an object variable or an instance
a = Employee('Mario', 886012, 200000, "Intern")    
  
# calling a function of the class Person using its instance
a.display()

# %%
# Parent class
class Person(object):
    # constructor
    def __init__(self, fname, lname, age):
        self.fname = fname
        self.lname = lname
        self.age = age
    def print_P(self):
        print(self.fname)
        print(self.lname)
        print(self.age)
# Child class
class Student(Person):
    #Constructor
    def __init__(self, fname, lname, age, semester):
        self.semester = semester
        #
        Person.__init__(self,fname,lname,age) 
        #super().__init__(self,fname,lname,age) 

    #def print_C(self):
    #    print(self.semester)
    def print_P(self):
        print(self.semester)

# %%
s = Student('Diana','Rivera',22,'2018')
s.print_P()
#s.print_C()

# %%
def product(a, b):
    p = a * b
    print(p)

# %%
def product(a, b, c):
    p = a * b*c
    print(p)

# %%
class Animal:
    multicellular = True
    eukaryotic

# %%
class Person:

  def __init__(self, f_name, l_name):
    self.first_name = f_name
    self.last_name = l_name

  def print_name(self,**args):
        for i in args:
            print(i,'=>',args[i])


class Student(Person):

    def __init__(self, f_name,m_name,l_name):
        super().__init__(f_name, l_name)
        self.middle_name = m_name

x = Student("Raghav","D","Thakkar")
x.print_name(firstname=x.first_name,middlename=x.middle_name,lastname=x.last_name)

# %%
class Animal:
    # properties
	multicellular = True
	# Eukaryotic means Cells with Nucleus
	eukaryotic = True
	
	# function breathe
	def breathe(self):
	    print("I breathe oxygen.")
    
    # function feed
	def feed(self):
	    print("I eat food.")
        
class Herbivorous(Animal):
    
    # function feed
	def feed(self):
	    print("I eat only plants. I am vegetarian.")
        
herbi = Herbivorous()
herbi.feed()
# calling some other function
herbi.breathe()

# %% [markdown]
# https://pynative.com/python-encapsulation/

# %%
class Employee:
    # constructor
    def __init__(self, name, salary):
        self.name = name
        # private member
        self.__salary = salary

    def show(self):
        print("Name: ", self.name, 'Salary:', self.__salary)

emp = Employee('Ana', 40)

# calling public method of the class
emp.show()

# %%
class Employee:
    def __init__(self, name, salary):
        # public data member
        self.name = name
        # private member
        self.__salary = salary

# creating object of a class
emp = Employee('Jessa', 10000)

# accessing private data members
print('Salary:', emp.__salary)

# %% [markdown]
# ## Name mangling to access private members

# %% [markdown]
# ## Polymorphism

# %% [markdown]
# Polymorphism in Built-in function len()
#
# The built-in function len() calculates the length of an object depending upon its type. If an object is a string, it returns the count of characters, and If an object is a list, it returns the count of items in a list.
#
# The len() method treats an object as per its class type.mro

# %%
students = ['Ana','Katy']
school = 'ABC school'
print(len(students))
print(len(school))

# %% [markdown]
# # Polymorphism With Inheritance

# %%
class Vehicle:
    
    def __init__(self,name,color,price):
        self.name = name
        self.color = color
        self.price = price
    
    def show(self):
        print('Details:',self.name, self.color, self.price)
    
    def max_speed(self):
        print('Vehicle max speed is 150')

    def change_gear(self):
        print('Vehicle change 6 gear')


        
class Car(Vehicle):
    def max_speed(self):
        print('Car max speed is 240')

    def change_gear(self):
        print('Car change 7 gear')

class Truck(Vehicle):
    def max_speed(self):
        print('Truck max speed is 180')

    def change_gear(self):
        print('Truck change 7 gear')
        
        

# Car Object
car = Car('Car x1', 'Red', 20000)
car.show()

print('\n')

# calls methods from Car class
car.max_speed()
car.change_gear()
print('\n')

# Vehicle Object
vehicle = Vehicle('Truck x1', 'white', 75000)
vehicle.show()

# calls method from a Vehicle class
vehicle.max_speed()
vehicle.change_gear()
print('\n')

truck = Truck('Volvo','blue',18000)
truck.show()

# %%
## Polymorphism in class methods

# %%
class Ferrari:
    
    def model(name):
        print('Ferrari F40')
        
    def details_type(price):
        print("$12000")

    def max_speed(self):
        print("Max speed 350")     
    
class BMW:
    def model(name):
        print('BMW 520')
        
    def details_type(color):
        print("Blue")

    def max_speed(self):
        print("Max speed is 240")
         
        
class Nissan:
    def model(name):
        print('Versa')
        
    def details_type(capacity):
        print("41 l")

    def max_speed(self):
        print("Max speed is 180")
        
    

ferrari = Ferrari()
bmw = BMW()
nissan = Nissan() 

type = input('Do you want to see our luxurious line? : ')
if type == 'yes': 
    for car in (ferrari, bmw):
        car.model()
        car.details_type()
        car.max_speed()
        
        
else:
    nissan.model()
    nissan.details_type()
    nissan.max_speed()


    
    
##Implementar inheritance
# Out:
# Do you want to see our luxurious line? : yes
# Ferrari F40
# $12000
# Max speed 350
# BMW 520
# Blue
# Max speed is 240

# %%
class Point:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y

    def __str__(self):
        return "({0},{1})".format(self.x, self.y)

    def __lt__(self, other):
        self_mag = (self.x ** 2) + (self.y ** 2)
        other_mag = (other.x ** 2) + (other.y ** 2)
        return self_mag < other_mag
    
    def __ge__(self, other):
        self_mag = (self.x ** 2) + (self.y ** 2)
        other_mag = (other.x ** 2) + (other.y ** 2)
        return self_mag >= other_mag
          
    def __le__(self, other):
        self_mag = (self.x ** 2) + (self.y ** 2)
        other_mag = (other.x ** 2) + (other.y ** 2)
        return self_mag <= other_mag
    
p1 = Point(1,1)
p2 = Point(-2,-3)
p3 = Point(1,-1)

# use less than
print(p1<p2)
print(p2<p3)
print(p1<p3)
print(p1>=p2)
print(p1<=p2)
# Out:
# True
# False
# False
# False
# True

# %%
# Out:
# False

# %% [markdown]
# ## Iterator

# %% [markdown]
# Iterator is an object that is used to iterate over iterable objects like lists,tuple,dicts, and sets.
#
# To initialize we use iter()
#
# It uses the method next() for iteration

# %%
iterable_value = 'Hola a todos'
iterable_obj = iter(iterable_value)
 
while True:
    try: 
        # Iterate by calling next
        item = next(iterable_obj)
        print(item)
    except StopIteration: 
        # exception will happen when iteration will over
        break
# Out:
# H
# o
# l
# a
#
# a
#
# t
# o
# d
# o
# s

# %%
# A simple Python program to demonstrate
# working of iterators using an example type
# that iterates from 10 to given value
 
# An iterable user defined type
class Test:
 
    # Constructor
    def __init__(self, limit):
        self.limit = limit
 
    # Creates iterator object
    # Called when iteration is initialized
    def __iter__(self):
        self.x = 10
        return self
 
    # To move to next element. In Python 3,
    # we should replace next with __next__
    def __next__(self):
 
        # Store current value ofx
        x = self.x
 
        # Stop iteration if limit is reached
        if x > self.limit:
            raise StopIteration
 
        # Else increment and return old value
        self.x = x + 1;
        return x
# Prints numbers from 10 to 15
for i in Test(15):
    print(i)
 # Prints nothing
for i in Test(5):
    print(i)
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
# Sample built-in iterators
 
# Iterating over a list
print("List Iteration")
l = ["Hola", "a", "todos"]
for i in l:
    print(i)
     
# Iterating over a tuple (immutable)
print("\nTuple Iteration")
t = ("geeks", "for", "geeks")
for i in t:
    print(i)
     
# Iterating over a String
print("\nString Iteration")   
s = "Geeks"
for i in s :
    print(i)
     
# Iterating over dictionary
print("\nDictionary Iteration")  
d = dict()
d['xyz'] = 123
d['abc'] = 345
for i in d :
    print("%s  %d" %(i, d[i]))
# Out:
# List Iteration
# Hola
# a
# todos
#
# Tuple Iteration
# geeks
# for
# geeks
#
# String Iteration
# G
# e
# e
# k
# s
#
# Dictionary Iteration
# xyz  123
# abc  345

# %%
iterable_value = ["Hola", "a", "todos"]
iterable_obj = iter(iterable_value)
 
while True:
    try: 
        # Iterate by calling next
        item = next(iterable_obj)
        print(item)
    except StopIteration: 
        # exception will happen when iteration will over
        break
# Out:
# Hola
# a
# todos

# %%
d = dict()
d['xyz'] = 123
d['abc'] = 345
iterable_value = d
iterable_obj = iter(iterable_value)
 
while True:
    try: 
        # Iterate by calling next
        item = next(iterable_obj)
        print(item)
    except StopIteration: 
        # exception will happen when iteration will over
        break
# Out:
# xyz
# abc

# %%
d = dict()
d['xyz'] = 123
d['abc'] = 345
d['Hola']= 1234
d['AMIGOS'] = 123456
iterable_value = d
iterable_obj = iter(iterable_value)
 
for i in d:
    try: 
        # Iterate by calling next
        item = next(iterable_obj)
        print("%s  %d" %(item, d[item]))
    except StopIteration: 
        # exception will happen when iteration will over
        break
# Out:
# xyz  123
# abc  345
# Hola  1234
# AMIGOS  123456

# %%
# define a list
my_list = [4, 7, 0, 3]

# get an iterator using iter()
my_iter = iter(my_list)

# iterate through it using next()

# Output: 4
print(next(my_iter))

# Output: 7
print(next(my_iter))

# next(obj) is same as obj.__next__()

# Output: 0
print(my_iter.__next__())

# Output: 3
print(my_iter.__next__())

# This will raise error, no items left
next(my_iter)
# Out:
# 4
# 7
# 0
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-17-f674730df03a> in <module>
#      22
#      23 # This will raise error, no items left
# ---> 24 next(my_iter)
#
# StopIteration:

# %%
class PowThree:
    """Class to implement an iterator
    of powers of three"""

    def __init__(self, max=0):
        self.max = max

    def __iter__(self):
        self.n = 0
        return self

    def __next__(self):
        if self.n <= self.max:
            result = 3 ** self.n
            self.n += 1
            return result
        else:
            raise StopIteration


for i in PowThree(5):
    print(i)
# Out:
# 1
# 3
# 9
# 27
# 81
# 243

# %%
iterable_value = ["Hola", "a", "todos"]
iterable_obj = iter(iterable_value)
 
while True:
    try: 
        # Iterate by calling next
        item = next(iterable_obj)
        print(item)
    except StopIteration: 
        # exception will happen when iteration will over
        break
# Out:
# Hola
# a
# todos

# %%
class Student:
    def __init__(self,name,scores=None):
        self.name = name        
        if scores:
            self.scores = scores
        else:
            self.scores = []
    def average(self):
        average = sum(self.scores)/ len(self.scores) 
        return average

class Classroom:
    def __init__(self, name, students=None):
        self.name = name
        self.students = students 
        if students:
            self.students = students
        else:
            self.students = []

    def average(self):
        scores = []
        for student in self.students:
            scores += student.scores
        return sum(scores) / len(scores)

# %%
carlos = Student("Carlos Ruiz Zafon",scores=[8, 10])
daniel = Student("Daniel Sempere",scores=[4, 10, 10])
print(daniel.name + " average is " + str(daniel.average()))
print(carlos.name + " average is " + str(carlos.average()))

chemestry = Classroom("chemestry", students=[carlos, jim])
print(f"The average of '{chemestry.name}' class is {chemestry.average()}.")
# Out:
# Daniel Sempere average is 8.0
# Carlos Ruiz Zafon average is 9.0
# The average of 'chemestry' class is 8.4.

# %%
class Student:

    def __init__(self, name, phone, scores=None):
        self.name = name
        self.phone = phone
        if scores:
            self.scores = scores
        else:
            self.scores = []


    def average(self):
        return sum(self.scores) / len(self.scores)


class Classroom:

    def __init__(self, name, students=None):
        self.name = name
        self.students = students if students else []

    def average(self):
        scores = []
        for student in self.students:
            scores += student.scores
        return sum(scores) / len(scores)


#if __name__ == '__main__':
    john = Student("John smith", "0102030405", scores=[12, 13])
    jim = Student("Jim Morison", "0506070809", scores=[13, 15, 18])
   math = Classroom("math", students=[john, jim])

    print(john.name + " average is " + str(john.average()))
#    print("{} average is {:2.2f}.".format(jim.name, jim.average()))
    print(f"The average of '{math.name}' class is {math.average}.")

#    print(john.phone)
#    john.phone = "0101010101"
#    print(john.phone)

#    print(type(john), type(math))
# Out:
# John smith average is 12.5

# %%
def temperature(t):
    def celcius2fahrenheit(x):
        return 9* x/5 +32
    result = "It's "+str(celcius2fahrenheit(t))+"degrees"
    return result
print(temperature(20))
# Out:
# It's 68.0degrees
