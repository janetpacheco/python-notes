# %% [markdown]
# ## Python conditions and If statements

# %% [markdown]
# Python supports the usual logical conditions from mathematics:
#
#     Equals: a == b
#     Not Equals: a != b
#     Less than: a < b
#     Less than or equal to: a <= b
#     Greater than: a > b
#     Greater than or equal to: a >= b

# %% [markdown]
# ## Elif
# The **elif** keyword is pythons way of saying "if the previous conditions were not true, then try this condition".

# %%
a = 10
b = 10
if b > a:
    print('b is greater than a')
elif b == a:
    print('a and b are equal ')
# Out:
# a and b are equal

# %% [markdown]
# ## Else

# %%
a = 200
b = 33
if b > a:
    print("b is greater than a")
elif a == b:
    print("a and b are equal")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# ## Short hand if
# **If you have only one statement** to execute, you can put it on the same line as the if statement.

# %%
print(a,b) 
if a > b: print("a is greater than b")
# Out:
# 200 33
# a is greater than b

# %% [markdown]
# ## Short Hand If ... Else
#
#
# This technique is known as **Ternary Operators**, or **Conditional Expressions**.

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# One line if else statement, with 3 conditions:

# %%
a = 1
b = 20
print('a') if a > b else print('=') if a==b else print('b is greater than a')
# Out:
# b is greater than a

# %% [markdown]
# ## And

# %%
a = 20
b = 33
c = 50
if a > b and c > a :
    print('Both condictions are True')
else:
    print('Both condictions aren\'t True')
# Out:
# Both condictions aren't True

# %% [markdown]
# ## Or

# %%
a = 120
b = 33
c = 120
if a==b or c > b :
    print('At least one condition is True')
# Out:
# At least one condition is True

# %% [markdown]
# ## Nested If

# %%
x = 41
if x > 10:
    print('Above ten,')
    if x == 20:
        print('Equal to 20')
    else: 
        print('Else interior : Otra cosa')
# Out:
# Above ten,
# Else interior : Otra cosa

# %% [markdown]
# ## The pass Statement
# **if** statements cannot be empty, but **if** you for some reason have an **if** statement with no content, put in the **pass** statement to avoid getting an error.

# %%
a = 33
b = 200

if b > a:
    pass
